# %%
import pandas as pd
import os
import sys
sys.path.insert(0, "../")
from factor_cal.config_loader import basic_config as cfg
from factor_cal.feature import features as fe
from factor_cal.factor import factors as fa
from factor_cal.utils import tools as tl
from factor_cal.factor import factor_func as ff

# %%
# read config file
config = cfg.BasicConfig('config/config.yml')
fac_names = []
for facType in config['factors']:
    fac_names += list(config['factors'][facType].keys())
    
features = fe.Features(config)
factors = fa.Factors(config, features)

# %%
# ic_results = pd.DataFrame({c: pd.Series(dtype=t) for c, t in {'IC Mean': 'float', 'IC Std.': 'float', 'Risk-Adjusted IC': 'float', 'IC_win rate': 'float'}.items()})

# %%
fac_names
# Out:
# ['close_ret',
#  'td_pv_corr_1min',
#  'td_pv_corr',
#  'ret_v_prod_5min',
#  'ret_v_prod_1min',
#  'td_ret_v_prod_5min',
#  'td_ret_v_prod_1min',
#  'td_p_v_ratio_3s_1min',
#  'td_p_v_ratio_3s_5min',
#  'close_ret_15min',
#  'close_ret_5min',
#  'close_ret_1min',
#  'ohlc_rat',
#  'clh',
#  'clh_delta',
#  'td_buy_rank',
#  'td_sell_rank',
#  'close_adjusted',
#  'ret_skew',
#  'ret_kurt',
#  'retail_dir_tsrank_10min',
#  'retail_dir_rowrank',
#  'OB_price_2derivative',
#  'OB_price_2derivative_tsrank',
#  'wb1_tsrank',
#  'wb5_tsrank',
#  'wb10_tsrank',
#  'td_v_ratio',
#  'en_b_p10_tsrank',
#  'en_s_p10_tsrank',
#  'en_b_ret10_tsrank',
#  'en_s_ret10_tsrank',
#  'en_b_p5_tsrank',
#  'en_s_p5_tsrank',
#  'en_b_ret5_tsrank',
#  'en_s_ret5_tsrank',
#  'bs_v1_tsrank',
#  'bs_v5_tsrank',
#  'bs_pv1_tsrank',
#  'bs_pv5_tsrank',
#  'en_bs_price_diff',
#  'en_b_price_tsrank',
#  'en_s_price_tsrank',
#  'en_b_sumprice_tsrank',
#  'en_s_sumprice_tsrank',
#  'ct_b_med_tsrank',
#  'ct_s_med_tsrank',
#  'can_en_v_ratio',
#  'can_en_v_ratio_fillna']

# %%
base_dir = r'/home/wangzirui/workspace/factor_ic_summary/factor_comb_top_n/OB_price'

ic_results = None
pred_type = '1m'
for fac_name in fac_names:
    try:
        cur_res = pd.read_csv(os.path.join(base_dir, f'{fac_name}.csv'), index_col=0)
    except FileNotFoundError as e:
        print(e)
        continue
    cur_res = cur_res.loc[pred_type, ['IC Mean', 'IC Std.', 'Risk-Adjusted IC', 'IC win rate']]
    cur_df = pd.DataFrame(cur_res).T
    cur_df['factor'] = fac_name
    cur_df['formula'] = str(factors.fac_dict.get(fac_name))
    cur_df['description'] = factors.fac_dict.get(fac_name).desc
    ic_results = pd.concat([ic_results, cur_df], axis=0, ignore_index=True)

# %%
ic_results
# Out:
#      IC Mean   IC Std.  Risk-Adjusted IC  IC win rate  \
# 0   0.017537  0.026245          0.668198     0.763530
# 1   0.014317  0.036070          0.396907     0.660848
# 2   0.021526  0.032195          0.668618     0.764261
# 3   0.017683  0.071441          0.247523     0.600195
# 4   0.017683  0.071441          0.247523     0.600195
# 5   0.015611  0.053116          0.293914     0.619503
# 6   0.009715  0.041341          0.235007     0.581521
# 7   0.008714  0.040048          0.217583     0.574256
# 8   0.014673  0.052279          0.280662     0.613457
# 9  -0.005285  0.103328         -0.051145     0.457972
# 10 -0.008294  0.090135         -0.092017     0.455583
# 11  0.008002  0.062584          0.127855     0.567577
# 12  0.016637  0.067606          0.246091     0.616285
# 13  0.011393  0.023303          0.488901     0.716919
# 14  0.005495  0.016714          0.328790     0.630180
# 15  0.045878  0.040700          1.127230     0.881667
# 16 -0.011263  0.044235         -0.254613     0.405168
# 17 -0.004193  0.087595         -0.047868     0.500975
# 18 -0.010751  0.046818         -0.229628     0.381521
# 19  0.018877  0.036635          0.515266     0.697952
# 20  0.035094  0.031458          1.115567     0.883569
# 21  0.083833  0.040738          2.057845     0.979327
# 22 -0.009821  0.019165         -0.512451     0.285666
# 23 -0.011548  0.019552         -0.590619     0.265919
# 24  0.122460  0.033362          3.670621     0.999610
# 25  0.096762  0.035378          2.735095     0.997367
# 26  0.080717  0.054662          1.476676     0.929059
# 27  0.046510  0.038987          1.192949     0.888298
# 28  0.034740  0.073919          0.469973     0.702584
# 29 -0.000580  0.080383         -0.007214     0.518723
# 30  0.012252  0.034407          0.356084     0.636568
# 31  0.028684  0.032919          0.871330     0.831009
# 32  0.024294  0.078904          0.307897     0.646806
# 33  0.000334  0.083354          0.004004     0.524768
# 34  0.011471  0.035920          0.319357     0.627060
# 35  0.026672  0.033635          0.792984     0.806728
# 36  0.125216  0.035542          3.523065     0.999366
# 37  0.106360  0.040264          2.641550     0.996636
# 38  0.124563  0.035514          3.507439     0.999366
# 39  0.106125  0.040294          2.633772     0.996392
# 40 -0.280906  0.083891         -3.348478     0.000146
# 41 -0.037494  0.027877         -1.345013     0.084349
# 42  0.081284  0.024371          3.335342     0.996928
# 43  0.027228  0.036797          0.739973     0.798147
# 44  0.034491  0.032182          1.071755     0.872940
# 45  0.034158  0.043075          0.792988     0.798391
# 46  0.010584  0.042901          0.246701     0.589907
# 47  0.044786  0.027755          1.613617     0.954217
# 48  0.038326  0.025767          1.487407     0.941492
#
#                          factor  \
# 0                     close_ret
# 1               td_pv_corr_1min
# 2                    td_pv_corr
# 3               ret_v_prod_5min
# 4               ret_v_prod_1min
# 5            td_ret_v_prod_5min
# 6            td_ret_v_prod_1min
# 7          td_p_v_ratio_3s_1min
# 8          td_p_v_ratio_3s_5min
# 9               close_ret_15min
# 10               close_ret_5min
# 11               close_ret_1min
# 12                     ohlc_rat
# 13                          clh
# 14                    clh_delta
# 15                  td_buy_rank
# 16                 td_sell_rank
# 17               close_adjusted
# 18                     ret_skew
# 19                     ret_kurt
# 20      retail_dir_tsrank_10min
# 21           retail_dir_rowrank
# 22         OB_price_2derivative
# 23  OB_price_2derivative_tsrank
# 24                   wb1_tsrank
# 25                   wb5_tsrank
# 26                  wb10_tsrank
# 27                   td_v_ratio
# 28              en_b_p10_tsrank
# 29              en_s_p10_tsrank
# 30            en_b_ret10_tsrank
# 31            en_s_ret10_tsrank
# 32               en_b_p5_tsrank
# 33               en_s_p5_tsrank
# 34             en_b_ret5_tsrank
# 35             en_s_ret5_tsrank
# 36                 bs_v1_tsrank
# 37                 bs_v5_tsrank
# 38                bs_pv1_tsrank
# 39                bs_pv5_tsrank
# 40             en_bs_price_diff
# 41            en_b_price_tsrank
# 42            en_s_price_tsrank
# 43         en_b_sumprice_tsrank
# 44         en_s_sumprice_tsrank
# 45              ct_b_med_tsrank
# 46              ct_s_med_tsrank
# 47               can_en_v_ratio
# 48        can_en_v_ratio_fillna
#
#                                               formula  \
# 0                                 ret(close, shift=1)
# 1      ts_correlation(ffill_na(vwap), vol, window=20)
# 2                 ts_correlation(ffill_na(vwap), vol)
# 3     ts_rank(multiply(ret(close), vol), window=5*20)
# 4     ts_rank(multiply(ret(close), vol), window=1*20)
# 5   ts_rank(multiply(ret(ffill_na(vwap)), vol), wi...
# 6   ts_rank(multiply(ret(ffill_na(vwap)), vol), wi...
# 7   ts_rank(fill_na(divide(delta(ffill_na(vwap), s...
# 8   ts_rank(fill_na(divide(delta(ffill_na(vwap), s...
# 9                             ret(close, shift=15*20)
# 10                             ret(close, shift=5*20)
# 11                               ret(close, shift=20)
# 12    ohlc_ratio(open, high, low, close, window=3*20)
# 13  divide(subtract(add(close, close), add(low, hi...
# 14  delta(divide(subtract(add(close, close), add(l...
# 15  ts_rank(fill_na(multiply(td_buy_p, td_buy_v), ...
# 16  ts_rank(fill_na(multiply(td_sell_p, td_sell_v)...
# 17  fill_na(divide(subtract(close, ts_mean(close, ...
# 18         ts_skew(ret(close, shift=20), window=5*20)
# 19         ts_kurt(ret(close, shift=20), window=5*20)
# 20  ts_rank(fill_na(divide(subtract(add(mid_ab_m, ...
# 21  rank(fill_na(divide(subtract(add(mid_ab_m, sm_...
# 22  divide(subtract(add(bs_avg_price, move(bs_avg_...
# 23  ts_rank(subtract(add(bs_avg_price, move(bs_avg...
# 24                          ts_rank(wb1, window=5*20)
# 25                          ts_rank(wb5, window=5*20)
# 26                         ts_rank(wb10, window=5*20)
# 27  ts_rank(fill_na(divide(subtract(td_buy_v, td_s...
# 28  ts_rank(divide(bbv10_sum, bv10_sum), window=5*20)
# 29  ts_rank(divide(ssv10_sum, sv10_sum), window=5*20)
# 30  ts_rank(ret(divide(bbv10_sum, bv10_sum)), wind...
# 31  ts_rank(ret(divide(ssv10_sum, sv10_sum)), wind...
# 32    ts_rank(divide(bbv5_sum, bv5_sum), window=5*20)
# 33    ts_rank(divide(ssv5_sum, sv5_sum), window=5*20)
# 34  ts_rank(ret(divide(bbv5_sum, bv5_sum)), window...
# 35  ts_rank(ret(divide(ssv5_sum, sv5_sum)), window...
# 36   ts_rank(subtract(bv1_sum, sv1_sum), window=5*20)
# 37   ts_rank(subtract(bv5_sum, sv5_sum), window=5*20)
# 38  ts_rank(subtract(bbv1_sum, ssv1_sum), window=5...
# 39  ts_rank(subtract(bbv5_sum, ssv5_sum), window=5...
# 40  divide(subtract(fill_na_v2(en_buy_p, b1), fill...
# 41  ts_rank(subtract(fill_na_v2(en_buy_p, b1), bs_...
# 42  ts_rank(subtract(fill_na_v2(en_sell_p, s1), bs...
# 43  ts_rank(subtract(divide(ts_sum(multiply(en_buy...
# 44  ts_rank(subtract(divide(ts_sum(multiply(en_sel...
# 45       ts_rank(fill_na(inv(ct_b_med)), window=5*20)
# 46       ts_rank(fill_na(inv(ct_s_med)), window=5*20)
# 47  ts_rank(divide(subtract(add(en_buy_v, cancel_s...
# 48  ts_rank(fill_na(divide(subtract(add(en_buy_v, ...
#
#                                       description
# 0                                             收益率
# 1                                         价量之间相关性
# 2                                         价量之间相关性
# 3                                       收益率和成交量关系
# 4                                       收益率和成交量关系
# 5                                   加权成交价收益和成交量关系
# 6                                   加权成交价收益和成交量关系
# 7                                   加权成交价变动与成交量比值
# 8                                   加权成交价变动与成交量比值
# 9                                             收益率
# 10                                            收益率
# 11                                            收益率
# 12                                      收开价格的相对变化
# 13                              高收价格以及收低价格的相对变化之差
# 14                           高收价格以及收低价格的相对变化之差的变化
# 15                                  主动买入资金的时间维度排名
# 16                                  主动卖出资金的时间维度排名
# 17                                        标准化的收盘价
# 18                                         收益率的偏度
# 19                                         收益率的峰度
# 20                                散户买卖资金方向的时间维度排名
# 21                                散户买卖资金方向的标的维度排名
# 22                                    订单簿平均价的二阶导数
# 23                           订单簿平均价的二阶导数的时间维度排名""
# 24                                    1档委比的时间维度排名
# 25                                    5档委比的时间维度排名
# 26                                   10档委比的时间维度排名
# 27                              买卖成交量的相对比值的时间维度排名
# 28                             10档量加权挂单买入价的时间维度排名
# 29                             10档量加权挂单卖出价的时间维度排名
# 30                         10档量加权挂单买入价的变化率的时间维度排名
# 31                         10档量加权挂单卖出价的变化率的时间维度排名
# 32                              5档量加权挂单买入价的时间维度排名
# 33                              5档量加权挂单卖出价的时间维度排名
# 34                          5档量加权挂单买入价的变化率的时间维度排名
# 35                          5档量加权挂单卖出价的变化率的时间维度排名
# 36                                1档买卖挂单量差的时间维度排名
# 37                              5档买卖累计挂单量差的时间维度排名
# 38                             1档买卖累计挂单金额差的时间维度排名
# 39                             5档买卖累计挂单金额差的时间维度排名
# 40                        委托买卖价差的相对比值,缺失值使用盘口数据填充
# 41                             委托买入价与盘口均价差的时间维度排名
# 42                             委托卖出价与盘口均价差的时间维度排名
# 43                     半分钟内的平均委托买入价与盘口均价比值的时间维度排名
# 44                     半分钟内的平均委托卖出价与盘口均价比值的时间维度排名
# 45                               买单撤单时间中位数的时间维度排名
# 46                               卖单撤单时间中位数的时间维度排名
# 47           买卖双方量的相对比值的时间维度排名，其中买方量为委托买单以及卖方撤单之和
# 48  买卖双方量的相对比值的时间维度排名，其中买方量为委托买单以及卖方撤单之和,缺失值进行了填充

# %%
xlsx_file = os.path.join(base_dir, f'ic_summary_{pred_type}.xlsx')
ic_results.to_excel(xlsx_file, index=False)

# %%
from openpyxl import load_workbook
from openpyxl.styles import Font

df = pd.read_excel(xlsx_file, sheet_name='Sheet1')
book = load_workbook(xlsx_file)
sheet = book['Sheet1']

# %%
class Condition:
    def __init__(self, name, value, func):
        self._name = name
        self._value = value
        self._func = func
        
    @property
    def name(self):
        return self._name
    
    @property
    def value(self):
        return self._value
    
    @value.setter
    def value(self, value):
        self._value = value
    
    @property
    def index(self):
        return self._index
    
    @index.setter
    def index(self, index):
        self._index = index
    
    def is_satisfied(self, value):
        return self._func(value, self._value)

def abs_cond(value, threshold):
    return abs(value) > threshold

def win_rate_cond(value, threshold):
    return abs(value-0.5) > threshold

def determine_index(dic, conditions, name, index):
    for condition in conditions:
        if name == condition._name:
            condition.index = index
            dic[index] = condition

fac_index = None
satisfied_factors = []
conditions = [Condition('IC Mean', 0.03, abs_cond), Condition('Risk-Adjusted IC', 1.5, abs_cond), Condition('IC win rate', 0.3, win_rate_cond)]
cond_ind_dict = {}
for i, row in enumerate(sheet.iter_rows()):
    if i == 0:
        for j, cell in enumerate(row):
            if cell.value == 'factor':
                fac_index = j
                continue
            determine_index(cond_ind_dict, conditions, cell.value, j)
    else:
        satisfied_cond_num = 0
        factor_name = None
        for j, cell in enumerate(row):
            if j == fac_index:
                factor_name = cell.value
                continue
            if j in cond_ind_dict.keys():
                condition = cond_ind_dict[j]
                if condition.is_satisfied(cell.value):
                    satisfied_cond_num += 1
                    cell.font = Font(color='FF0000')
            
        if satisfied_cond_num >= 2:
            satisfied_factors.append(factor_name)
            
            
xlsx_file = os.path.join(base_dir, f'ic_summary_{pred_type}_modified.xlsx')                  
book.save(xlsx_file)

# %%
import yaml
yaml.dump(satisfied_factors, open(os.path.join(base_dir, f'satisfied_factors_{pred_type}.yml'), 'w'))

# %%
pred_type='1m'
base_dir = r'C:\Users\12552\Downloads\ic_summary\factor_ic_summary'
factor_filepath = os.path.join(base_dir, f'satisfied_factors_{pred_type}.yml')
with open(factor_filepath, 'r') as f:
    factor_names = yaml.load(f, Loader=yaml.FullLoader)

# %%
factor_names

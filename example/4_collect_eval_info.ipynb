# %%
import pandas as pd
import os
import sys
sys.path.insert(0, "../")
from factor_cal.config_loader import basic_config as cfg
from factor_cal.feature import features as fe
from factor_cal.factor import factors as fa
from factor_cal.utils import tools as tl
from factor_cal.factor import factor_func as ff

# %%
# read config file
config = cfg.BasicConfig('config/config.yml')
fac_names = []
for facType in config['factors']:
    fac_names += list(config['factors'][facType].keys())
    
features = fe.Features(config)
factors = fa.Factors(config, features)

# %%
# ic_results = pd.DataFrame({c: pd.Series(dtype=t) for c, t in {'IC Mean': 'float', 'IC Std.': 'float', 'Risk-Adjusted IC': 'float', 'IC_win rate': 'float'}.items()})

# %%
fac_names
# Out:
# ['close_ret',
#  'td_pv_corr_1min',
#  'td_pv_corr',
#  'ret_v_prod_5min',
#  'ret_v_prod_1min',
#  'td_ret_v_prod_5min',
#  'td_ret_v_prod_1min',
#  'td_p_v_ratio_3s_1min',
#  'td_p_v_ratio_3s_5min',
#  'close_ret_15min',
#  'close_ret_5min',
#  'close_ret_1min',
#  'ohlc_rat',
#  'clh',
#  'clh_delta',
#  'td_buy_rank',
#  'td_sell_rank',
#  'close_adjusted',
#  'ret_skew',
#  'ret_kurt',
#  'retail_dir_tsrank_10min',
#  'retail_dir_rowrank',
#  'OB_price_2derivative',
#  'OB_price_2derivative_tsrank',
#  'wb1_tsrank',
#  'wb5_tsrank',
#  'wb10_tsrank',
#  'td_v_ratio',
#  'en_b_p10_tsrank',
#  'en_s_p10_tsrank',
#  'en_b_ret10_tsrank',
#  'en_s_ret10_tsrank',
#  'en_b_p5_tsrank',
#  'en_s_p5_tsrank',
#  'en_b_ret5_tsrank',
#  'en_s_ret5_tsrank',
#  'bs_v1_tsrank',
#  'bs_v5_tsrank',
#  'bs_pv1_tsrank',
#  'bs_pv5_tsrank',
#  'en_bs_price_diff',
#  'en_b_price_tsrank',
#  'en_s_price_tsrank',
#  'en_b_sumprice_tsrank',
#  'en_s_sumprice_tsrank',
#  'ct_b_med_tsrank',
#  'ct_s_med_tsrank',
#  'can_en_v_ratio',
#  'can_en_v_ratio_fillna']

# %%
proc_type = "bid_ask_price"
base_dir = rf'/home/wangzirui/workspace/factor_ic_summary/factor_comb_top_n/{proc_type}'

ic_results = None
pred_type = '1m'
for fac_name in fac_names:
    try:
        cur_res = pd.read_csv(os.path.join(base_dir, f'{fac_name}.csv'), index_col=0)
    except FileNotFoundError as e:
        print(e)
        continue
    cur_res = cur_res.loc[pred_type, ['IC Mean', 'IC Std.', 'Risk-Adjusted IC', 'IC win rate']]
    cur_df = pd.DataFrame(cur_res).T
    cur_df['factor'] = fac_name
    cur_df['formula'] = str(factors.fac_dict.get(fac_name))
    cur_df['description'] = factors.fac_dict.get(fac_name).desc
    ic_results = pd.concat([ic_results, cur_df], axis=0, ignore_index=True)

# %%
ic_results
# Out:
#      IC Mean   IC Std.  Risk-Adjusted IC  IC win rate  \
# 0   0.015887  0.026180          0.606848     0.729412
# 1   0.015075  0.030116          0.500576     0.693661
# 2   0.009729  0.047754          0.203733     0.561855
# 3   0.010939  0.032036          0.341471     0.630132
# 4   0.014671  0.028879          0.508028     0.691893
# 5   0.039793  0.080166          0.496386     0.700412
# 6   0.027349  0.050750          0.538904     0.716911
# 7   0.031394  0.061354          0.511676     0.703016
# 8   0.024459  0.042262          0.578754     0.728775
# 9   0.023381  0.041761          0.559867     0.721803
# 10  0.030416  0.061137          0.497514     0.698959
# 11 -0.018468  0.093827         -0.196825     0.379917
# 12 -0.024356  0.070013         -0.347876     0.324571
# 13 -0.017001  0.052111         -0.326239     0.342492
# 14 -0.022727  0.070850         -0.320769     0.355575
# 15  0.015801  0.019527          0.809201     0.797544
# 16  0.008935  0.016298          0.548216     0.707865
# 17  0.023429  0.037272          0.628586     0.742733
# 18 -0.060937  0.028018         -2.174922     0.017657
# 19 -0.029297  0.084722         -0.345799     0.351020
# 20  0.009699  0.037262          0.260281     0.605708
# 21  0.003417  0.029246          0.116846     0.554423
# 22  0.043043  0.026594          1.618542     0.960172
# 23  0.057304  0.029737          1.927040     0.981947
# 24 -0.009126  0.018193         -0.501611     0.295086
# 25 -0.006442  0.018589         -0.346569     0.357856
# 26  0.116137  0.042070          2.760583     0.999826
# 27  0.099606  0.039246          2.537998     0.996963
# 28  0.094385  0.052138          1.810276     0.968937
# 29  0.058761  0.030083          1.953279     0.977137
# 30 -0.043332  0.064146         -0.675517     0.241041
# 31 -0.011322  0.068082         -0.166301     0.435922
# 32  0.024071  0.026356          0.913297     0.829898
# 33  0.010111  0.032820          0.308065     0.613409
# 34 -0.042951  0.067776         -0.633719     0.252278
# 35 -0.023054  0.071570         -0.322121     0.370195
# 36  0.022381  0.027363          0.817931     0.802039
# 37  0.010980  0.034392          0.319254     0.619614
# 38  0.103794  0.039762          2.610409     0.999046
# 39  0.094099  0.040617          2.316763     0.992495
# 40  0.104479  0.039723          2.630170     0.999089
# 41  0.094355  0.040489          2.330347     0.992711
# 42  0.319505  0.101467          3.148876     0.995950
# 43  0.099698  0.026395          3.777191     0.999046
# 44 -0.053579  0.028345         -1.890245     0.035445
# 45  0.048091  0.028403          1.693155     0.955729
# 46  0.019301  0.025122          0.768292     0.781727
# 47 -0.033203  0.035042         -0.947530     0.161432
# 48 -0.023378  0.034852         -0.670769     0.245336
# 49  0.047621  0.026616          1.789185     0.967852
# 50  0.039620  0.024468          1.619225     0.959566
# 51  0.047609  0.026600          1.789803     0.968113
# 52  0.039234  0.024484          1.602422     0.958742
# 53  0.035537  0.027957          1.271122     0.909650
# 54  0.130533  0.063242          2.064022     0.974752
# 55 -0.114765  0.021097         -5.439970     0.000000
# 56 -0.024038  0.041976         -0.572669     0.243699
# 57 -0.000315  0.023657         -0.013329     0.496492
# 58 -0.003584  0.022579         -0.158711     0.426765
# 59  0.052611  0.027879          1.887145     0.976691
#
#                          factor  \
# 0                     close_ret
# 1                       pv_corr
# 2               td_pv_corr_5min
# 3               td_pv_corr_1min
# 4                    td_pv_corr
# 5               ret_v_prod_5min
# 6               ret_v_prod_1min
# 7            td_ret_v_prod_5min
# 8            td_ret_v_prod_1min
# 9          td_p_v_ratio_3s_1min
# 10         td_p_v_ratio_3s_5min
# 11              close_ret_15min
# 12               close_ret_5min
# 13               close_ret_1min
# 14                     ohlc_rat
# 15                          clh
# 16                    clh_delta
# 17                  td_buy_rank
# 18                 td_sell_rank
# 19               close_adjusted
# 20                     ret_skew
# 21                     ret_kurt
# 22      retail_dir_tsrank_10min
# 23           retail_dir_rowrank
# 24         OB_price_2derivative
# 25  OB_price_2derivative_tsrank
# 26                   wb1_tsrank
# 27                   wb5_tsrank
# 28                  wb10_tsrank
# 29                   td_v_ratio
# 30              en_b_p10_tsrank
# 31              en_s_p10_tsrank
# 32            en_b_ret10_tsrank
# 33            en_s_ret10_tsrank
# 34               en_b_p5_tsrank
# 35               en_s_p5_tsrank
# 36             en_b_ret5_tsrank
# 37             en_s_ret5_tsrank
# 38                 bs_v1_tsrank
# 39                 bs_v5_tsrank
# 40                bs_pv1_tsrank
# 41                bs_pv5_tsrank
# 42             en_bs_price_diff
# 43            en_b_price_tsrank
# 44            en_s_price_tsrank
# 45         en_b_sumprice_tsrank
# 46         en_s_sumprice_tsrank
# 47              ct_b_med_tsrank
# 48              ct_s_med_tsrank
# 49               can_en_v_ratio
# 50        can_en_v_ratio_fillna
# 51              can_en_pv_ratio
# 52       can_en_pv_ratio_fillna
# 53      best_v_imbalance_tsrank
# 54                     bs_press
# 55       OB_price_spread_tsrank
# 56                 td_price_std
# 57               en_b_price_std
# 58               en_s_price_std
# 59         en_v_order_inbalance
#
#                                               formula  \
# 0                                 ret(close, shift=1)
# 1                          ts_correlation(close, vol)
# 2    ts_correlation(ffill_na(vwap), vol, window=5*20)
# 3      ts_correlation(ffill_na(vwap), vol, window=20)
# 4                 ts_correlation(ffill_na(vwap), vol)
# 5     ts_rank(multiply(ret(close), vol), window=5*20)
# 6     ts_rank(multiply(ret(close), vol), window=1*20)
# 7   ts_rank(multiply(ret(ffill_na(vwap)), vol), wi...
# 8   ts_rank(multiply(ret(ffill_na(vwap)), vol), wi...
# 9   ts_rank(fill_na(divide(delta(ffill_na(vwap), s...
# 10  ts_rank(fill_na(divide(delta(ffill_na(vwap), s...
# 11                            ret(close, shift=15*20)
# 12                             ret(close, shift=5*20)
# 13                               ret(close, shift=20)
# 14    ohlc_ratio(open, high, low, close, window=3*20)
# 15  divide(subtract(add(close, close), add(low, hi...
# 16  delta(divide(subtract(add(close, close), add(l...
# 17  ts_rank(fill_na(multiply(td_buy_p, td_buy_v), ...
# 18  ts_rank(fill_na(multiply(td_sell_p, td_sell_v)...
# 19  fill_na(divide(subtract(close, ts_mean(close, ...
# 20         ts_skew(ret(close, shift=20), window=5*20)
# 21         ts_kurt(ret(close, shift=20), window=5*20)
# 22  ts_rank(fill_na(divide(subtract(add(mid_ab_m, ...
# 23  rank(fill_na(divide(subtract(add(mid_ab_m, sm_...
# 24  divide(subtract(add(bs_avg_price, move(bs_avg_...
# 25  ts_rank(subtract(add(bs_avg_price, move(bs_avg...
# 26                          ts_rank(wb1, window=5*20)
# 27                          ts_rank(wb5, window=5*20)
# 28                         ts_rank(wb10, window=5*20)
# 29  ts_rank(fill_na(divide(subtract(td_buy_v, td_s...
# 30  ts_rank(divide(bbv10_sum, bv10_sum), window=5*20)
# 31  ts_rank(divide(ssv10_sum, sv10_sum), window=5*20)
# 32  ts_rank(ret(divide(bbv10_sum, bv10_sum)), wind...
# 33  ts_rank(ret(divide(ssv10_sum, sv10_sum)), wind...
# 34    ts_rank(divide(bbv5_sum, bv5_sum), window=5*20)
# 35    ts_rank(divide(ssv5_sum, sv5_sum), window=5*20)
# 36  ts_rank(ret(divide(bbv5_sum, bv5_sum)), window...
# 37  ts_rank(ret(divide(ssv5_sum, sv5_sum)), window...
# 38   ts_rank(subtract(bv1_sum, sv1_sum), window=5*20)
# 39   ts_rank(subtract(bv5_sum, sv5_sum), window=5*20)
# 40  ts_rank(subtract(bbv1_sum, ssv1_sum), window=5...
# 41  ts_rank(subtract(bbv5_sum, ssv5_sum), window=5...
# 42  divide(subtract(fill_na_v2(en_buy_p, b1), fill...
# 43  ts_rank(subtract(fill_na_v2(en_buy_p, b1), bs_...
# 44  ts_rank(subtract(fill_na_v2(en_sell_p, s1), bs...
# 45  ts_rank(subtract(ffill_na(divide(ts_sum(multip...
# 46  ts_rank(subtract(ffill_na(divide(ts_sum(multip...
# 47       ts_rank(fill_na(inv(ct_b_med)), window=5*20)
# 48       ts_rank(fill_na(inv(ct_s_med)), window=5*20)
# 49  ts_rank(divide(subtract(add(en_buy_v, cancel_s...
# 50  ts_rank(fill_na(divide(subtract(add(en_buy_v, ...
# 51  ts_rank(divide(subtract(add(multiply(en_buy_v,...
# 52  ts_rank(fill_na(divide(subtract(add(multiply(e...
# 53  ts_rank(best_v_imbalance(bv1_sum, b1, sv1_sum,...
# 54                bs_press(press_buy_v, press_sell_v)
# 55               ts_rank(subtract(s1, b1), window=20)
# 56  ts_rank(ts_std(ffill_na(vwap), window=20), win...
# 57  ts_rank(ts_std(en_buy_p, window=20), window=3*20)
# 58  ts_rank(ts_std(en_sell_p, window=20), window=3...
# 59  fill_na(divide(subtract(en_buy_v, en_sell_v), ...
#
#                                          description
# 0                                                收益率
# 1                                            价量之间相关性
# 2                                            价量之间相关性
# 3                                            价量之间相关性
# 4                                            价量之间相关性
# 5                                          收益率和成交量关系
# 6                                          收益率和成交量关系
# 7                                      加权成交价收益和成交量关系
# 8                                      加权成交价收益和成交量关系
# 9                                      加权成交价变动与成交量比值
# 10                                     加权成交价变动与成交量比值
# 11                                               收益率
# 12                                               收益率
# 13                                               收益率
# 14                                         收开价格的相对变化
# 15                                 高收价格以及收低价格的相对变化之差
# 16                              高收价格以及收低价格的相对变化之差的变化
# 17                                     主动买入资金的时序截面排名
# 18                                     主动卖出资金的时序截面排名
# 19                                           标准化的收盘价
# 20                                            收益率的偏度
# 21                                            收益率的峰度
# 22                                   散户买卖资金方向的时序截面排名
# 23                                    散户买卖资金方向的横维度排名
# 24                                       订单簿平均价的二阶导数
# 25                              订单簿平均价的二阶导数的时序截面排名""
# 26                                       1档委比的时序截面排名
# 27                                       5档委比的时序截面排名
# 28                                      10档委比的时序截面排名
# 29                                 买卖成交量的相对比值的时序截面排名
# 30                                10档量加权挂单买入价的时序截面排名
# 31                                10档量加权挂单卖出价的时序截面排名
# 32                            10档量加权挂单买入价的变化率的时序截面排名
# 33                            10档量加权挂单卖出价的变化率的时序截面排名
# 34                                 5档量加权挂单买入价的时序截面排名
# 35                                 5档量加权挂单卖出价的时序截面排名
# 36                             5档量加权挂单买入价的变化率的时序截面排名
# 37                             5档量加权挂单卖出价的变化率的时序截面排名
# 38                                   1档买卖挂单量差的时序截面排名
# 39                                 5档买卖累计挂单量差的时序截面排名
# 40                                1档买卖累计挂单金额差的时序截面排名
# 41                                5档买卖累计挂单金额差的时序截面排名
# 42                           委托买卖价差的相对比值,缺失值使用盘口数据填充
# 43                                委托买入价与盘口均价差的时序截面排名
# 44                                委托卖出价与盘口均价差的时序截面排名
# 45                        半分钟内的平均委托买入价与盘口均价差值的时序截面排名
# 46                        半分钟内的平均委托卖出价与盘口均价差值的时序截面排名
# 47                                  买单撤单时间中位数的时序截面排名
# 48                                  卖单撤单时间中位数的时序截面排名
# 49              买卖双方量的相对比值的时序截面排名，其中买方量为委托买单以及卖方撤单之和
# 50     买卖双方量的相对比值的时序截面排名，其中买方量为委托买单以及卖方撤单之和,缺失值进行了填充
# 51            买卖双方金额的相对比值的时序截面排名，其中买方金额为委托买单以及卖方撤单之和
# 52  买卖双方金额的相对比值的时序截面排名，其中买方金额为委托买单以及卖方撤单之和, 缺失值进行了填充
# 53                                最优买卖挂单量变化之差的时序截面排名
# 54                       买卖压力, 压力是根据挂单价格的倒数为权重的挂单量之和
# 55                                       挂单价差的时序截面排名
# 56                                  加权成交价的标准差的时序截面排名
# 57                                  委托买入价的标准差的时序截面排名
# 58                                  委托卖出价的标准差的时序截面排名
# 59                                        委托买卖量的相对比值

# %%
xlsx_file = os.path.join(base_dir, f'ic_summary_{pred_type}.xlsx')
ic_results.to_excel(xlsx_file, index=False)

# %%
from openpyxl import load_workbook
from openpyxl.styles import Font

df = pd.read_excel(xlsx_file, sheet_name='Sheet1')
book = load_workbook(xlsx_file)
sheet = book['Sheet1']

# %%
class Condition:
    def __init__(self, name, value, func):
        self._name = name
        self._value = value
        self._func = func
        
    @property
    def name(self):
        return self._name
    
    @property
    def value(self):
        return self._value
    
    @value.setter
    def value(self, value):
        self._value = value
    
    @property
    def index(self):
        return self._index
    
    @index.setter
    def index(self, index):
        self._index = index
    
    def is_satisfied(self, value):
        return self._func(value, self._value)

def abs_cond(value, threshold):
    return abs(value) > threshold

def win_rate_cond(value, threshold):
    return abs(value-0.5) > threshold

def determine_index(dic, conditions, name, index):
    for condition in conditions:
        if name == condition._name:
            condition.index = index
            dic[index] = condition

fac_index = None
satisfied_factors = []
conditions = [Condition('IC Mean', 0.03, abs_cond), Condition('Risk-Adjusted IC', 1.5, abs_cond), Condition('IC win rate', 0.3, win_rate_cond)]
cond_ind_dict = {}
for i, row in enumerate(sheet.iter_rows()):
    if i == 0:
        for j, cell in enumerate(row):
            if cell.value == 'factor':
                fac_index = j
                continue
            determine_index(cond_ind_dict, conditions, cell.value, j)
    else:
        satisfied_cond_num = 0
        factor_name = None
        for j, cell in enumerate(row):
            if j == fac_index:
                factor_name = cell.value
                continue
            if j in cond_ind_dict.keys():
                condition = cond_ind_dict[j]
                if condition.is_satisfied(cell.value):
                    satisfied_cond_num += 1
                    cell.font = Font(color='FF0000')
            
        if satisfied_cond_num >= 2:
            satisfied_factors.append(factor_name)
            
            
xlsx_file = os.path.join(base_dir, f'ic_summary_{pred_type}_modified.xlsx')                  
book.save(xlsx_file)

# %%
satisfied_factors = ic_results[abs(ic_results['IC Mean']) > 0.025]['factor'].to_list()

# %%
import yaml
yaml.dump(satisfied_factors, open(os.path.join(base_dir, f'satisfied_factors_{pred_type}.yml'), 'w'))

# %%
pred_type='1m'
base_dir = r'C:\Users\12552\Downloads\ic_summary\factor_ic_summary'
factor_filepath = os.path.join(base_dir, f'satisfied_factors_{pred_type}.yml')
with open(factor_filepath, 'r') as f:
    factor_names = yaml.load(f, Loader=yaml.FullLoader)

# %%
factor_names
